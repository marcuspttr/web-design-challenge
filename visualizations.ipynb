# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
cities_df = pd.read_csv('Resources/cities.csv')

# %%
cities_df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
html = cities_df.to_html()

html_text = open("data.html", "w")
html_text.write(html)
html_text.close()

# %%
northern_df = cities_df[cities_df['Lat']>=0]
southern_df = cities_df[cities_df['Lat']<0]

# %%
# Finding the linear regression information.
(slope, intercept, rvalue, _, _) = linregress(northern_df['Lat'],northern_df['Max Temp'])

# Creating the best fit line to be overlaid on the graph later.
fit = slope*northern_df['Lat']+intercept

# Creating the intial scatterplot.
northern_df.plot.scatter(x = 'Lat', y = 'Max Temp', grid = True, alpha = 0.50)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)") 
plt.title(f'Linear Regression \nNorthern Hemisphere: Latitude vs. Max Temperature')

# Adding the best line over the graph.
plt.plot(northern_df['Lat'], fit ,"-", color = "red")

# Overlaying the equation for the line in a clean to read manner.
plt.annotate(f'y = {round(slope, 2)}x +{round(intercept, 2)}', 
[10, 40], color = 'red', fontsize = 15)

# Cleaning up the image and printing the r-value.
plt.tight_layout()
plt.savefig('assets/NorthLatTemp.png')
plt.show()

# %%
northern_df.plot.scatter(x = 'Lat', y = 'Max Temp', grid = True, alpha = 0.50)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)") 
plt.title(f'Northern Hemisphere: Latitude vs. Max Temperature')
plt.tight_layout()
plt.savefig('assets/NLTPreview.png')
plt.show()

# %%
(slope, intercept, rvalue, _, _) = linregress(southern_df['Lat'],southern_df['Max Temp'])
fit = slope*southern_df['Lat']+intercept


southern_df.plot.scatter(x = 'Lat', y = 'Max Temp', grid = True, alpha = 0.50)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)") 
plt.title(f'Linear Regression \nSouthern Hemisphere: Latitude vs. Max Temperature')

plt.plot(southern_df['Lat'], fit ,"-", color = "red")
plt.annotate(f'y = {round(slope, 2)}x +{round(intercept, 2)}', 
[-24, 50], color = 'red', fontsize = 15)

plt.tight_layout()
plt.savefig('assets/SouthLatTemp.png')
plt.show()

# %%
southern_df.plot.scatter(x = 'Lat', y = 'Max Temp', grid = True, alpha = 0.50)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)") 
plt.title(f'Southern Hemisphere: Latitude vs. Max Temperature')
plt.tight_layout()
plt.savefig('assets/SLTPreview.png')
plt.show()

# %%
(slope, intercept, rvalue, _, _) = linregress(northern_df['Lat'],northern_df['Wind Speed'])
fit = slope*northern_df['Lat']+intercept


northern_df.plot.scatter(x = 'Lat', y = 'Wind Speed', grid = True, alpha = 0.50) 
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.title(f'Linear Regression \nNorthern Hemisphere:Latitude vs. Wind Speed (mph)')

plt.plot(northern_df['Lat'], fit ,"-", color = "red")
plt.annotate(f'y = {round(slope, 2)}x +{round(intercept, 2)}', [0, 25], color = 'red', fontsize = 15)

plt.tight_layout()
plt.savefig('assets/NorthLatWind.png')
plt.show()

# %%
northern_df.plot.scatter(x = 'Lat', y = 'Wind Speed', grid = True, alpha = 0.50) 
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.title(f'Northern Hemisphere:Latitude vs. Wind Speed (mph)')
plt.tight_layout()
plt.savefig('assets/NLWPreview.png')
plt.show()

# %%
(slope, intercept, rvalue, _, _) = linregress(southern_df['Lat'],southern_df['Wind Speed'])
fit = slope*southern_df['Lat']+intercept


southern_df.plot.scatter(x = 'Lat', y = 'Wind Speed', grid = True, alpha = 0.50)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f'Linear Regression \nSouthern Hemisphere: Latitude vs. Wind Speed (mph')

plt.plot(southern_df['Lat'], fit ,"-", color = "red")
plt.annotate(f'y = {round(slope, 2)}x +{round(intercept, 2)}', [-55, 24], color = 'red', fontsize = 15)

plt.tight_layout()
plt.savefig('assets/SouthLatWind.png')
plt.show()

# %%
southern_df.plot.scatter(x = 'Lat', y = 'Wind Speed', grid = True, alpha = 0.50)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f'Southern Hemisphere: Latitude vs. Wind Speed (mph)')
plt.tight_layout()
plt.savefig('assets/SLWPreview.png')
plt.show()
